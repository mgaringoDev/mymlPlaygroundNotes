# %% [markdown]
# REF:
# - [In Depth Linear Regression](https://jakevdp.github.io/PythonDataScienceHandbook/05.06-linear-regression.html#Gaussian-Basis)
# - [SKLearn Gaussian Process](https://scikit-learn.org/stable/modules/gaussian_process.html)
# - [Quick Start to Gaussian Process](https://towardsdatascience.com/quick-start-to-gaussian-process-regression-36d838810319)
# - [Understanding Gaussian Basis function parameters](https://stats.stackexchange.com/questions/117556/understanding-gaussian-basis-function-parameters-to-be-used-in-linear-regression)

# %%
import numpy as np
import pandas as pd

# Visualization
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %% [markdown]
# # Functions

# %%
def getData():
    db = 'C:/Cerebral/_MarioSandBox/DB/mlPlayground/linearRegressionDB_BrainHeadMass.csv'
    dataset = pd.read_csv(db)
    dataset.head()    
    x = np.array(dataset['Head Size(cm^3)'].tolist())
    y = np.array(dataset['Brain Weight(grams)'].tolist())
    return x,y

# %%
def plotData(dataX,dataY,xlab='Head Size(cm^3)',ylab='Brain Weight(grams)'):
    plt.scatter(dataX,dataY)
    plt.xlabel(xlab)
    plt.ylabel(ylab)
    plt.show()

# %%
def normData(dataX):
    mu = np.mean(dataX, 0)
    sigma = np.std(dataX, 0)
    dataX = (dataX-mu) / sigma 
    return dataX

# %%
def plotModel(dataX,dataY,model,xlab='Head Size(cm^3)',ylab='Brain Weight(grams)'):
    xMax = np.max(dataX)
    xMin = np.min(dataX)
    nPoints = 1000
    
    xfit = np.linspace(xMin, xMax, yMax)
    yfit = model.predict(xfit[:, np.newaxis])
    
    plt.scatter(x, y) 
    plt.xlabel(xlab)
    plt.ylabel(ylab)    
    plt.plot(xfit, yfit,'r')
    plt.show()

# %% [markdown]
# # I/O

# %%
db = 'C:/Cerebral/_MarioSandBox/DB/mlPlayground/linearRegressionDB_BrainHeadMass.csv'

# %%
dataset = pd.read_csv(db)
print(dataset.shape)
dataset.head()
# Out:
# (237, 4)
#    Gender  Age Range  Head Size(cm^3)  Brain Weight(grams)
# 0       1          1             4512                 1530
# 1       1          1             3738                 1297
# 2       1          1             4261                 1335
# 3       1          1             3777                 1282
# 4       1          1             4177                 1590

# %%
xLabel = 'Head Size(cm^3)'
yLabel = 'Brain Weight(grams)'
x = np.array(dataset['Head Size(cm^3)'].tolist())
y = np.array(dataset['Brain Weight(grams)'].tolist())

# %%
plotData(x,y,xLabel,yLabel)

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
# get data
x,y = getData()

# create the model 
linearRegressionModel = LinearRegression(fit_intercept=True)

# normalize the data
x = normData(x)

# add a row of ones for the bias
x = x[:, np.newaxis]

# fit the features and y to the model
linearRegressionModel.fit(x, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
plotModel(x,y,linearRegressionModel)

# %% [markdown]
# Note that this looks very similar to the result we got for the notebook **"Linear Regression From Scratch Simple Approach"**

# %% [markdown]
# ## Model Parameters $\beta$

# %%
print("Model slope:    ", linearRegressionModel.coef_[0])
print("Model intercept:", linearRegressionModel.intercept_)
# Out:
# Model slope:     96.01736367001354
# Model intercept: 1282.873417721519

# %% [markdown]
# # Basis Function

# %% [markdown]
# ## Polynomial Basis Function

# %%
from sklearn.preprocessing import PolynomialFeatures

# %% [markdown]
# In this example we take a set of features and transform them using the polynomial basis function
#
# $$y=a_0+a_1x+a_2x^2+a_3x^3+...+a_nx^n$$
#
# where n = 3

# %%
x = np.array([2, 3, 4])
x
# Out:
# array([2, 3, 4])

# %% [markdown]
# This will give a bias column so you don't have to add it in numpy like we were doing before with
# ```python
# >>> x = x[:, np.newaxis]
# ```

# %%
poly = PolynomialFeatures(3, include_bias=True)
poly.fit_transform(x[:, None])
# Out:
# array([[ 1.,  2.,  4.,  8.],
#        [ 1.,  3.,  9., 27.],
#        [ 1.,  4., 16., 64.]])

# %%
poly = PolynomialFeatures(3, include_bias=False)
poly.fit_transform(x[:, None])
# Out:
# array([[ 2.,  4.,  8.],
#        [ 3.,  9., 27.],
#        [ 4., 16., 64.]])

# %% [markdown]
# ### Using pipelines

# %%
from sklearn.pipeline import make_pipeline

# %% [markdown]
# First transform the data into n=7 polynomial basis function then apply linear regression modeling on the newly created data

# %%
polyModel = make_pipeline(PolynomialFeatures(7),
                           LinearRegression())

# %% [markdown]
# Generate a bunch of random points on a sin function of the form $f(x) = sin(x)+noise$ where $noise = 0.1*randomValues$

# %%
rng = np.random.RandomState(1)
x = 10 * rng.rand(50)
y = np.sin(x) + 0.1 * rng.randn(50)

# %% [markdown]
# Fit using the pipeline we just created

# %%
polyModel.fit(x[:, np.newaxis], y)
xfit = np.linspace(0, 10, 1000)
yfit = polyModel.predict(xfit[:, np.newaxis])

plt.scatter(x, y)
plt.plot(xfit, yfit,'r')
plt.show()

# %% [markdown]
# Lets play around with the model order of the model and see what happens when we increase and decrease the value of the model

# %%
def polyModelOrder(n=7):
    polyModel = make_pipeline(PolynomialFeatures(n),
                           LinearRegression())
    rng = np.random.RandomState(1)
    x = 10 * rng.rand(50)
    y = np.sin(x) + 0.1 * rng.randn(50)
    polyModel.fit(x[:, np.newaxis], y)
    xfit = np.linspace(0, 10, 1000)
    yfit = polyModel.predict(xfit[:, np.newaxis])

    plt.scatter(x, y)
    plt.plot(xfit, yfit,'r')
    plt.show()

# %%
polyModelOrder(3)

# %%
polyModelOrder(5)

# %%
polyModelOrder(10)

# %%
polyModelOrder(16)

# %% [markdown]
# With the data projected to the 16-dimensional basis, the model has far too much flexibility and goes to extreme values between locations where it is constrained by data.

# %% [markdown]
# ## Gaussian Basis Function

# %% [markdown]
# We need to create our own transformation function to be placed in the pipeline.  To do so we must import
# ```python
# from sklearn.base import BaseEstimator, TransformerMixin
# ```
# [BaseEstimator](https://scikit-learn.org/stable/modules/generated/sklearn.base.BaseEstimator.html)
# [TransformerMixin](https://scikit-learn.org/stable/modules/generated/sklearn.base.TransformerMixin.html)
#
#
# For a step by step example follow this [crossValidated](https://stats.stackexchange.com/questions/117556/understanding-gaussian-basis-function-parameters-to-be-used-in-linear-regression) forum question.

# %% [markdown]
# Recall that the Gaussian bases are made up of not polynomial functions but multiple Gaussian functions with various spacing **s** in the form:
#
# $$\phi_j(x) = exp(\frac{-(x-\mu_j)^2}{2s^2})$$

# %%
from sklearn.base import BaseEstimator, TransformerMixin

# %%
class GaussianFeatures(BaseEstimator, TransformerMixin):
    """Uniformly spaced Gaussian features for one-dimensional input"""
    
    def __init__(self, N, width_factor=2.0):
        self.N = N
        self.width_factor = width_factor
    
    @staticmethod
    def _gauss_basis(x, y, width, axis=None):
        arg = (x - y) / width
        return np.exp(-0.5 * np.sum(arg ** 2, axis))
        
    def fit(self, X, y=None):
        # create N centers spread along the data range
        self.centers_ = np.linspace(X.min(), X.max(), self.N)
        self.width_ = self.width_factor * (self.centers_[1] - self.centers_[0])
        return self
        
    def transform(self, X):
        return self._gauss_basis(X[:, :, np.newaxis], self.centers_,
                                 self.width_, axis=1)

# %%
numberOfGaussians = 20
gauss_model = make_pipeline(GaussianFeatures(numberOfGaussians),
                            LinearRegression())
gauss_model.fit(x[:, np.newaxis], y)
yfit = gauss_model.predict(xfit[:, np.newaxis])

plt.scatter(x, y)
plt.plot(xfit, yfit)
plt.xlim(0, 10);

# %% [markdown]
# Similar to the polynomial basis function the larger the number of gaussians you have to add up the more the model overfits the data. The model has far too much flexibility and goes to extreme values between locations where it is constrained by data. We can see the reason for this if we plot the coefficients of the Gaussian bases with respect to their locations:

# %%
def basis_plot(model, title=None):
    fig, ax = plt.subplots(2, sharex=True)
    model.fit(x[:, np.newaxis], y)
    ax[0].scatter(x, y)
    ax[0].plot(xfit, model.predict(xfit[:, np.newaxis]))
    ax[0].set(xlabel='x', ylabel='y', ylim=(-1.5, 1.5))
    
    if title:
        ax[0].set_title(title)

    ax[1].plot(model.steps[0][1].centers_,
               model.steps[1][1].coef_)
    ax[1].set(xlabel='basis location',
              ylabel='coefficient',
              xlim=(0, 10))

# %%
model = make_pipeline(GaussianFeatures(10), LinearRegression())
basis_plot(model)

# %%
model = make_pipeline(GaussianFeatures(20), LinearRegression())
basis_plot(model)

# %%
model = make_pipeline(GaussianFeatures(30), LinearRegression())
basis_plot(model)

# %% [markdown]
# Notice that the coefficients of the basis function of the 30 Gaussian functions.  This is typical over-fitting behavior when **basis functions overlap: the coefficients of adjacent basis functions blow up and cancel each other out**. We know that such behavior is problematic, and it would be nice if **we could limit such spikes expliticly in the model by penalizing large values of the model parameters** using regularization.

# %% [markdown]
# # Regularization

# %% [markdown]
# ## L2 Regularization
#
# This regularization penalizes the sum of squares (2-norms) of the model coefficients.
#
# $$P = \alpha\sum_{N}^{n=1}\theta^2_n$$
#
# here $\alpha$ is a free parameter that controls the strength of the penalty. You can think of this as controlling the complexity of the resulting model.  In the $\lim_{\alpha\to 0}$, we recover the standard linear regression results.  While the $\lim_{\alpha\to\infty}$ all model responses will be suppressed.

# %%
from sklearn.linear_model import Ridge
model = make_pipeline(GaussianFeatures(30), Ridge(alpha=0.1))
basis_plot(model, title='Ridge Regression')

# %%
model = make_pipeline(GaussianFeatures(30), Ridge(alpha=10))
basis_plot(model, title='Ridge Regression')

# %% [markdown]
# Notice that the when $\alpha$ is closer to 0 it acts more like the linear regression, with come spikes of the coefficients, and as you increase the value of $\alpha$ you only get about 2 Gaussians.

# %% [markdown]
# ## Lasso Regression (L1 Regularization)
# This regularization penalizes the sum of absolute values (1-norms) of the model coefficients.
#
# $$P = \alpha\sum_{N}^{n=1}|\theta_n|$$
#
# This type of regularization favours **sparse models** where possible, where it preferentially sets model coefficients to exactly zero.  With the lasso regression penalty, the majority of the coefficients are exactly zero, with the functional behavior being modeled by a small subset of the available basis functions.

# %%
from sklearn.linear_model import Lasso
model = make_pipeline(GaussianFeatures(30), Lasso(alpha=0.001))
basis_plot(model, title='Ridge Regression')
# Out:
# C:\Users\HP\Anaconda2\envs\mlPlaygroundPy36\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0021358158704902763, tolerance: 0.002065280097246271
#   positive)

# %%
model = make_pipeline(GaussianFeatures(30), Lasso(alpha=0.00001))
basis_plot(model, title='Ridge Regression')
# Out:
# C:\Users\HP\Anaconda2\envs\mlPlaygroundPy36\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.05709601947650125, tolerance: 0.002065280097246271
#   positive)

# %% [markdown]
# As $\alpha$ gets closer and closer to 0 the coefficients become less and less sparse.
