# %% [markdown]
# # Introduction
#
# This notebook is just to show which modules are installed and which version of python is installed.

# %%
import sys
print(sys.executable)
print(sys.version)
print(sys.version_info)
# Out:
# C:\Users\HP\Anaconda2\envs\mlPlaygroundPy36\python.exe
# 3.6.6 |Anaconda custom (64-bit)| (default, Jun 28 2018, 11:27:44) [MSC v.1900 64 bit (AMD64)]
# sys.version_info(major=3, minor=6, micro=6, releaselevel='final', serial=0)

# %%
# !conda list
# Out:
# # packages in environment at C:\Users\HP\Anaconda2\envs\mlPlaygroundPy36:
# #
# # Name                    Version                   Build  Channel
# _anaconda_depends         2019.03                  py36_0
# absl-py                   0.6.1                    pypi_0    pypi
# alabaster                 0.7.12                     py_0    conda-forge
# anaconda                  custom           py36h363777c_0
# anaconda-client           1.7.2                      py_0    conda-forge
# anaconda-project          0.8.3                      py_0    conda-forge
# asn1crypto                1.3.0                    py36_0    conda-forge
# astor                     0.7.1                    pypi_0    pypi
# astroid                   2.3.3                    py36_1    conda-forge
# astropy                   4.0              py36hfa6e2cd_1    conda-forge
# atomicwrites              1.3.0                      py_0    conda-forge
# ...

# %% [markdown]
# **Ref:**
# - [Conda RTD](https://kapeli.com/cheat_sheets/Conda.docset/Contents/Resources/Documents/index)
